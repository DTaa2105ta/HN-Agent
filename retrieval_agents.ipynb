# %% [markdown]
# ## Let's install the dependencies and login to our HF account to access the Inference API
#
# If you haven't installed `smolagents` yet, you can do so by running the following command:the dependencies and login to our HF account to access the Inference API

# %%
# !pip install smolagents
# Out:
# Requirement already satisfied: smolagents in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (1.24.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from smolagents) (0.36.2)
# Requirement already satisfied: requests>=2.32.3 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from smolagents) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from smolagents) (14.3.2)
# Requirement already satisfied: jinja2>=3.1.4 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from smolagents) (12.1.0)
# Requirement already satisfied: python-dotenv in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from smolagents) (1.2.1)
# Requirement already satisfied: filelock in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (2026.2.0)
# Requirement already satisfied: packaging>=20.9 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from jinja2>=3.1.4->smolagents) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from requests>=2.32.3->smolagents) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from requests>=2.32.3->smolagents) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from requests>=2.32.3->smolagents) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from requests>=2.32.3->smolagents) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from rich>=13.9.4->smolagents) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from rich>=13.9.4->smolagents) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Requirement already satisfied: colorama in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.31.2->smolagents) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Let's also login to the Hugging Face Hub to have access to the Inference API.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
from huggingface_hub import login
token = os.environ.get("HF_TOKEN")

login(token=token)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Basic Retrieval with WebSerach
#
# Let's build a simple agent that can search the web. This agent will retrieve information and synthesize responses to answer queries. With Agentic RAG, Alfred's agent can:
#
# * Search for latest superhero party trends
# * Refine results to include luxury elements
# * Synthesize information into a complete plan
#
# Here's how Alfred's agent can achieve this:

# %%
import os
from smolagents import CodeAgent, DuckDuckGoSearchTool, LiteLLMModel

gemini_api_key = os.getenv("GEMINI_API_KEY")
model_id = os.getenv("MODEL_ID", "gemini/gemini-2.5-flash")

if not gemini_api_key:
    raise ValueError("GEMINI_API_KEY is required for Gemini via LiteLLM")

# Initialize the search tool
search_tool = DuckDuckGoSearchTool()

model = LiteLLMModel(model_id=model_id, api_key=gemini_api_key)

agent = CodeAgent(
    model = model,
    tools=[search_tool]
 )

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
 )
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.5-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   party_ideas_search = web_search(query="luxury superhero themed party ideas decorations entertainment catering")
#   print(party_ideas_search)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [300+ Party Decoration Ideas for Memorable Celebrations
# -](https://www.shinny-party.com/blog/300+-party-decoration-ideas-for-memorable-celebrations-pinterest-2020/)
# ... party but struggling to come up with unique and creative decoration ideas ? Look no further than Pinterest for
# endless inspiration! With over 300 ideas ...
#
# [Birthday Party Catering Ideas: Unique Themes for All
# Ages](https://www.articleted.com/article/851037/281750/Birthday-Party-Catering-Ideas--Unique-Themes-for-All-Ages)
# Catering Sydney can tailor menus to complement popular themes like superhero adventures (think mini pizzas with
# superhero cutouts as toppings!), ...
#
# [Wedding & Party Network - Online wedding, special event
# and](https://www.weddingandpartynetwork.com/blog/tag/themed-parties/)
# ... themed party this summer? Here are a few tips and ideas ... We hope these ideas help and you have some fun
# inspiration for your beach themed party .
#
# [30 Elegant Christmas Party Themes & Ideas for a
# Stylish](https://www.catchmyparty.com/blog/elegant-christmas-party-themes)
# Timeless Holiday Luxury These glamorous Christmas party themes channel classic seasonal style — rich textures,
# glowing candlelight, and refined ...
#
# [Themed Party Designs: Essential Tips for Balance -
# Intrepid](https://www.intrepid21.com/themed-party-designs-essential-tips-for-balance/)
# Unleash your superhero powers with our action-packed collection of superhero-themed party supplies! Whether you're
# celebrating a birthday or hosting a heroic gathering, our assortment brings the excitement of comic books to life.
# From bold masks to vibrant tableware, our decorations ensure every aspect of your party exudes superhero flair.
# With high-quality materials and attention to detail, our supplies guarantee an unforgettable celebration where
# every guest can embrace their inner hero.
#
# Out: None
# [Step 3: Duration 4.01 seconds| Input tokens: 9,938 | Output tokens: 367]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer(
#       "Luxury superhero-themed party ideas:\n\n"
#       "**Decorations:**\n"
#       "- **Elegant Color Palette:** Focus on sophisticated versions of hero colors (e.g., deep reds, sapphire
#   blues, metallic golds and silvers, charcoal greys) instead of primary, cartoonish shades.\n"
#       "- **Custom Backdrops & Installations:** Create grand backdrops depicting Gotham-esque cityscapes, Stark
#   Tower-inspired modern architecture, or subtle S.H.I.E.L.D. agency aesthetics using high-quality materials,
#   projection mapping, or LED screens.\n"
#       "- **Subtle Branding:** Incorporate superhero logos (Batman symbol, S-shield, Avengers A) discreetly into
#   lighting, floor decals, ice sculptures, or even etched glassware, rather than overtly.\n"
#       "- **Sophisticated Lighting:** Use intelligent lighting to cast dramatic shadows, highlight key features,
#   and change colors dynamically to reflect different heroes or moods.\n"
#       "- **High-End Props:** Display museum-quality replicas of superhero artifacts (e.g., Captain America's
#   shield, Iron Man's helmet, Thor's hammer) on elegant pedestals or in display cases.\n"
#       "- **Floral Arrangements:** Utilize dark, dramatic flowers with touches of bright hero-specific colors,
#   arranged in modern, sleek vases.\n"
#       "- **Fabric Draping:** Use rich velvets, satins, and silks in thematic colors to drape walls or ceilings,
#   creating a luxurious atmosphere.\n\n"
#       "**Entertainment:**\n"
#       "- **Professional Performers:** Hire highly skilled actors in custom, movie-quality superhero costumes for
#   meet-and-greets, staged fight sequences, or even character-driven immersive experiences.\n"
#       "- **Aerialists & Stunt Shows:** Incorporate aerialists performing graceful feats, perhaps with capes or in
#   character, or professional stunt performers enacting thrilling superhero battles.\n"
#       "- **Live Music:** Feature an orchestra or a string quartet playing epic superhero movie scores, or a
#   sophisticated jazz band with subtle hero-themed arrangements.\n"
#       "- **Interactive Experiences:** Implement high-tech VR or AR stations where guests can 'train' with their
#   favorite heroes, a themed escape room, or a custom-built arcade featuring superhero games.\n"
#       "- **Photo Booth with Special Effects:** A photo booth equipped with green screen technology to place
#   guests in iconic superhero scenes, complete with props and professional lighting.\n"
#       "- **Laser Light Show/Projection Mapping:** Use advanced laser displays or projection mapping to transform
#   the venue walls into dynamic comic book panels, cityscapes, or cosmic battles.\n\n"
#       "**Catering:**\n"
#       "- **Gourmet Themed Menu:** Offer an elevated menu with creative names, such as 'Wakandan Salmon,'
#   'Kryptonian Quiches,' 'Spider-Sense Sliders,' or 'Gamma Green Gazpacho.'\n"
#       "- **Artisanal Food Stations:** Instead of a buffet, have specialized food stations: a 'Gotham City'
#   charcuterie board, a 'Metropolis' sushi bar, or a 'Stark Industries' molecular gastronomy station.\n"
#       "- **Signature Cocktails & Mocktails:** Develop a menu of sophisticated, color-coordinated drinks with
#   heroic names like 'The Bat Signal' (dark liquor), 'Hulk Smash' (green cocktail), or 'Captain's Shield' (red,
#   white, and blue layers).\n"
#       "- **Elaborate Dessert Bar:** Feature a show-stopping, multi-tiered cake with subtle superhero motifs,
#   alongside designer macarons, custom-molded chocolates, and petit fours, all themed and exquisitely
#   presented.\n"
#       "- **High-End Presentation:** Use premium dinnerware, crystal glassware, and elegant serving platters. Food
#   can be presented in artistic ways, subtly incorporating hero symbols or colors."
#   )
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Luxury superhero-themed party ideas:
#
# **Decorations:**
# - **Elegant Color Palette:** Focus on sophisticated versions of hero colors (e.g., deep reds, sapphire blues,
# metallic golds and silvers, charcoal greys) instead of primary, cartoonish shades.
# - **Custom Backdrops & Installations:** Create grand backdrops depicting Gotham-esque cityscapes, Stark
# Tower-inspired modern architecture, or subtle S.H.I.E.L.D. agency aesthetics using high-quality materials,
# projection mapping, or LED screens.
# - **Subtle Branding:** Incorporate superhero logos (Batman symbol, S-shield, Avengers A) discreetly into lighting,
# floor decals, ice sculptures, or even etched glassware, rather than overtly.
# - **Sophisticated Lighting:** Use intelligent lighting to cast dramatic shadows, highlight key features, and change
# colors dynamically to reflect different heroes or moods.
# - **High-End Props:** Display museum-quality replicas of superhero artifacts (e.g., Captain America's shield, Iron
# Man's helmet, Thor's hammer) on elegant pedestals or in display cases.
# - **Floral Arrangements:** Utilize dark, dramatic flowers with touches of bright hero-specific colors, arranged in
# modern, sleek vases.
# - **Fabric Draping:** Use rich velvets, satins, and silks in thematic colors to drape walls or ceilings, creating a
# luxurious atmosphere.
#
# **Entertainment:**
# - **Professional Performers:** Hire highly skilled actors in custom, movie-quality superhero costumes for
# meet-and-greets, staged fight sequences, or even character-driven immersive experiences.
# - **Aerialists & Stunt Shows:** Incorporate aerialists performing graceful feats, perhaps with capes or in
# character, or professional stunt performers enacting thrilling superhero battles.
# - **Live Music:** Feature an orchestra or a string quartet playing epic superhero movie scores, or a sophisticated
# jazz band with subtle hero-themed arrangements.
# - **Interactive Experiences:** Implement high-tech VR or AR stations where guests can 'train' with their favorite
# heroes, a themed escape room, or a custom-built arcade featuring superhero games.
# - **Photo Booth with Special Effects:** A photo booth equipped with green screen technology to place guests in
# iconic superhero scenes, complete with props and professional lighting.
# - **Laser Light Show/Projection Mapping:** Use advanced laser displays or projection mapping to transform the venue
# walls into dynamic comic book panels, cityscapes, or cosmic battles.
#
# **Catering:**
# - **Gourmet Themed Menu:** Offer an elevated menu with creative names, such as 'Wakandan Salmon,' 'Kryptonian
# Quiches,' 'Spider-Sense Sliders,' or 'Gamma Green Gazpacho.'
# - **Artisanal Food Stations:** Instead of a buffet, have specialized food stations: a 'Gotham City' charcuterie
# board, a 'Metropolis' sushi bar, or a 'Stark Industries' molecular gastronomy station.
# - **Signature Cocktails & Mocktails:** Develop a menu of sophisticated, color-coordinated drinks with heroic names
# like 'The Bat Signal' (dark liquor), 'Hulk Smash' (green cocktail), or 'Captain's Shield' (red, white, and blue
# layers).
# - **Elaborate Dessert Bar:** Feature a show-stopping, multi-tiered cake with subtle superhero motifs, alongside
# designer macarons, custom-molded chocolates, and petit fours, all themed and exquisitely presented.
# - **High-End Presentation:** Use premium dinnerware, crystal glassware, and elegant serving platters. Food can be
# presented in artistic ways, subtly incorporating hero symbols or colors.
# [Step 4: Duration 9.02 seconds| Input tokens: 15,740 | Output tokens: 1,732]
# Luxury superhero-themed party ideas:
#
# **Decorations:**
# - **Elegant Color Palette:** Focus on sophisticated versions of hero colors (e.g., deep reds, sapphire blues, metallic golds and silvers, charcoal greys) instead of primary, cartoonish shades.
# - **Custom Backdrops & Installations:** Create grand backdrops depicting Gotham-esque cityscapes, Stark Tower-inspired modern architecture, or subtle S.H.I.E.L.D. agency aesthetics using high-quality materials, projection mapping, or LED screens.
# - **Subtle Branding:** Incorporate superhero logos (Batman symbol, S-shield, Avengers A) discreetly into lighting, floor decals, ice sculptures, or even etched glassware, rather than overtly.
# - **Sophisticated Lighting:** Use intelligent lighting to cast dramatic shadows, highlight key features, and change colors dynamically to reflect different heroes or moods.
# - **High-End Props:** Display museum-quality replicas of superhero artifacts (e.g., Captain America's shield, Iron Man's helmet, Thor's hammer) on elegant pedestals or in display cases.
# - **Floral Arrangements:** Utilize dark, dramatic flowers with touches of bright hero-specific colors, arranged in modern, sleek vases.
# - **Fabric Draping:** Use rich velvets, satins, and silks in thematic colors to drape walls or ceilings, creating a luxurious atmosphere.
#
# **Entertainment:**
# - **Professional Performers:** Hire highly skilled actors in custom, movie-quality superhero costumes for meet-and-greets, staged fight sequences, or even character-driven immersive experiences.
# - **Aerialists & Stunt Shows:** Incorporate aerialists performing graceful feats, perhaps with capes or in character, or professional stunt performers enacting thrilling superhero battles.
# - **Live Music:** Feature an orchestra or a string quartet playing epic superhero movie scores, or a sophisticated jazz band with subtle hero-themed arrangements.
# - **Interactive Experiences:** Implement high-tech VR or AR stations where guests can 'train' with their favorite heroes, a themed escape room, or a custom-built arcade featuring superhero games.
# - **Photo Booth with Special Effects:** A photo booth equipped with green screen technology to place guests in iconic superhero scenes, complete with props and professional lighting.
# - **Laser Light Show/Projection Mapping:** Use advanced laser displays or projection mapping to transform the venue walls into dynamic comic book panels, cityscapes, or cosmic battles.
#
# **Catering:**
# - **Gourmet Themed Menu:** Offer an elevated menu with creative names, such as 'Wakandan Salmon,' 'Kryptonian Quiches,' 'Spider-Sense Sliders,' or 'Gamma Green Gazpacho.'
# - **Artisanal Food Stations:** Instead of a buffet, have specialized food stations: a 'Gotham City' charcuterie board, a 'Metropolis' sushi bar, or a 'Stark Industries' molecular gastronomy station.
# - **Signature Cocktails & Mocktails:** Develop a menu of sophisticated, color-coordinated drinks with heroic names like 'The Bat Signal' (dark liquor), 'Hulk Smash' (green cocktail), or 'Captain's Shield' (red, white, and blue layers).
# - **Elaborate Dessert Bar:** Feature a show-stopping, multi-tiered cake with subtle superhero motifs, alongside designer macarons, custom-molded chocolates, and petit fours, all themed and exquisitely presented.
# - **High-End Presentation:** Use premium dinnerware, crystal glassware, and elegant serving platters. Food can be presented in artistic ways, subtly incorporating hero symbols or colors.

# %% [markdown]
# The agent follows this process:
#
# 1. **Analyzes the Request:** Alfred’s agent identifies the key elements of the query—luxury superhero-themed party planning, with focus on decor, entertainment, and catering.
# 2. **Performs Retrieval:**  The agent leverages WebSearchTool to search for the most relevant and up-to-date information, ensuring it aligns with Alfred’s refined preferences for a luxurious event.
# 3. **Synthesizes Information:** After gathering the results, the agent processes them into a cohesive, actionable plan for Alfred, covering all aspects of the party.
# 4. **Stores for Future Reference:** The agent stores the retrieved information for easy access when planning future events, optimizing efficiency in subsequent tasks.

# %% [markdown]
# ## Custom Knowledge Base Tool
#
# For specialized tasks, a custom knowledge base can be invaluable. Let's create a tool that queries a vector database of technical documentation or specialized knowledge. Using semantic search, the agent can find the most relevant information for Alfred's needs.
#
# This approach combines predefined knowledge with semantic search to provide context-aware solutions for event planning. With specialized knowledge access, Alfred can perfect every detail of the party.
#
# Install the dependecies first and run!

# %%
# !pip install langchain langchain-community rank_bm25
# Out:
# Requirement already satisfied: langchain in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (1.2.9)
# Requirement already satisfied: langchain-community in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: rank_bm25 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (0.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.9 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain) (1.2.9)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.7 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain) (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (0.6.9)
# Requirement already satisfied: packaging>=23.2.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.9->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (0.3.4)
# Requirement already satisfied: xxhash>=3.5.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (0.25.0)
# Requirement already satisfied: anyio in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (4.12.1)
# Requirement already satisfied: certifi in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.0.9)
# Requirement already satisfied: idna in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-community) (2.0.46)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\fpt\capstone\agent\dummy\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, LiteLLMModel

gemini_api_key = os.getenv("GEMINI_API_KEY")
model_id = os.getenv("MODEL_ID", "gemini/gemini-2.5-flash")

if not gemini_api_key:
    raise ValueError("GEMINI_API_KEY is required for Gemini via LiteLLM")

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Alfred’s superhero-themed party at Wayne Manor."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)
docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

# Initialize the agent
model = LiteLLMModel(model_id=model_id, api_key=gemini_api_key)
agent = CodeAgent(tools=[party_planning_retriever], model=model)

# Example usage
response = agent.run(
    "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
 )

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options.      │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.5-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   party_ideas = party_planning_retriever(query="luxury superhero-themed party ideas for entertainment, catering,
#   and decoration")
#   final_answer(party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# ===== Idea 2 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 3 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 4 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
# [Step 1: Duration 1.72 seconds| Input tokens: 2,235 | Output tokens: 135]
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# ===== Idea 2 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 3 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 4 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.

# %% [markdown]
# This enhanced agent can:
# 1. First check the documentation for relevant information
# 2. Combine insights from the knowledge base
# 3. Maintain conversation context through memory
